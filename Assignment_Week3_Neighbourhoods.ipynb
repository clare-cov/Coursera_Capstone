# %% [markdown]
# # Assignment Week 3 Capstone Data Science

# %% [markdown]
# #### Import libraries required for assignment

# %%
#Required to open URL
import requests

# %%
#Install BeautifulSoup - comment out else when done
#!conda install -c conda-forge beautifulsoup4 --yes
from bs4 import BeautifulSoup

# %%
#Pandas library
import pandas as pd

# %%
#Install geocoder - comment out else when done
#!conda install -c conda-forge geocoder --yes
import geocoder

# %%
#Install geopy - comment out else when done
#!conda install -c conda-forge geopy --yes
import folium
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
import json # library to handle JSON files
# import k-means from clustering stage
from sklearn.cluster import KMeans
from pandas.io.json import json_normalize

# %%
import numpy as np # library to handle data in a vectorized manner

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ### First stage is to scrape the wiki page for the data and format data into a data frame.

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %% [markdown]
# #### Parse the HTML of the URL into a Beautiful Soup tree

# %%
soup = BeautifulSoup(website_url)

# %%
#Find the title
soup.title
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %% [markdown]
# #### Look through and find the required table. Data required starts with HTML tag "table"

# %%
#print(soup.prettify())

# %% [markdown]
# #### Bring back the table using find

# %%
pcode_table=soup.find('table', class_='wikitable sortable')
#pcode_table

# %% [markdown]
# #### Each row in the table is starts with "tr" and the data within is row is within "td".

# %% [markdown]
# ##### Loop through the pcode table and find the "tr" then the "td" tags. If the row has 3 columns then store the data in lists A (first column), B (second column) and C(third column).

# %%
A=[]
B=[]
C=[]

for row in pcode_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %%
#Have a quick check of the first element of the each list.
A[0]
# Out:
# 'M1A'

# %%
B[0]
# Out:
# 'Not assigned'

# %%
C[0]
# Out:
# 'Not assigned\n'

# %% [markdown]
# #### There appears to be some newlines in the columns. Use rstrip to go through list and clean.

# %%
j=0
for i in A:
    A[j]=i.rstrip()
    j=j+1
j=0
for i in B:
    B[j]=i.rstrip()
    j=j+1
j=0
for i in C:
    C[j]=i.rstrip()
    j=j+1

# %% [markdown]
# #### Import the pandas library and create a dataframe df with columns PostalCode, Borough and Neighbourhood and assign the column lists to the dataframe.

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Postal Code'])
df['Borough']=B
df['Neighbourhood']=C

# %% [markdown]
# #### Check the top and bottom of the dataframe to ensure it's captured

# %%
df.head()
# Out:
#   Postal Code           Borough     Neighbourhood
# 0         M1A      Not assigned      Not assigned
# 1         M2A      Not assigned      Not assigned
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront

# %%
df.tail()
# Out:
#     Postal Code       Borough          Neighbourhood
# 283         M8Z     Etobicoke              Mimico NW
# 284         M8Z     Etobicoke     The Queensway West
# 285         M8Z     Etobicoke  Royal York South West
# 286         M8Z     Etobicoke         South of Bloor
# 287         M9Z  Not assigned           Not assigned

# %% [markdown]
# #### Need to ensure that rows are removed that don't have a borough or neighbourhood assigned

# %%
df = df[df['Borough'] != 'Not assigned']

# %%
df.head()
# Out:
#   Postal Code           Borough     Neighbourhood
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront
# 5         M5A  Downtown Toronto       Regent Park
# 6         M6A        North York  Lawrence Heights

# %% [markdown]
# #### Combine neighbourhoods (comma seperated), and remove duplicate rows of Postalcodes and Boroughs.

# %%
dfnew = df.groupby(['Postal Code','Borough'])['Neighbourhood'].apply(','.join)

# %%
dfnew.head()
# Out:
# Postal Code  Borough
# M1B          Scarborough                           Rouge,Malvern
# M1C          Scarborough    Highland Creek,Rouge Hill,Port Union
# M1E          Scarborough         Guildwood,Morningside,West Hill
# M1G          Scarborough                                  Woburn
# M1H          Scarborough                               Cedarbrae
# Name: Neighbourhood, dtype: object

# %% [markdown]
# #### Convert back to a dataframe and reset the index

# %%
dfnew2 = pd.DataFrame(dfnew)
dfnew2 = dfnew2.reset_index()

# %%
dfnew2.head()
# Out:
#   Postal Code      Borough                         Neighbourhood
# 0         M1B  Scarborough                         Rouge,Malvern
# 1         M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2         M1E  Scarborough       Guildwood,Morningside,West Hill
# 3         M1G  Scarborough                                Woburn
# 4         M1H  Scarborough                             Cedarbrae

# %% [markdown]
# #### Change Neighbour to Borough if it's unassigned.

# %%
dfnew2.loc[(dfnew2['Neighbourhood'] == 'Not assigned'),'Neighbourhood']=dfnew2['Borough']

# %%
df = dfnew2

# %% [markdown]
# #### Shape of dataframe

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Second Stage of assignment is to get the Neighbourhood lats and longs

# %% [markdown]
# ##### Have attempted to use geocoder but it continually returns 'None'. Therefore will proceed to get lats and longs via the CSV

# %%
# initialize your variable to None
postal_code = "M1B"
# loop until you get the coordinates
#while(lat_lng_coords is None):
g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
lat_lng_coords = g.latlng
#latitude = lat_lng_coords[0]
#longitude = lat_lng_coords[1]

# %%
print(lat_lng_coords)
# Out:
# None

# %% [markdown]
# #### Read in Geo data from CSV file

# %%
dfgeo=pd.read_csv('Geospatial_Coordinates.csv')

# %%
dfgeo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# #### Now the lat long data is loaded will merge with scraped wiki data.

# %%
dfnew = df.merge(dfgeo,on=['Postal Code'],how='left')

# %%
dfnew.head()
# Out:
#   Postal Code      Borough                         Neighbourhood   Latitude  \
# 0         M1B  Scarborough                         Rouge,Malvern  43.806686
# 1         M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2         M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3         M1G  Scarborough                                Woburn  43.770992
# 4         M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# #### Check the size of the dataframe and change the name to 'neighbourhoods'

# %%
dfnew.shape
# Out:
# (103, 5)

# %%
neighbourhoods = dfnew

# %%
neighbourhoods.head()
# Out:
#   Postal Code      Borough                         Neighbourhood   Latitude  \
# 0         M1B  Scarborough                         Rouge,Malvern  43.806686
# 1         M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2         M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3         M1G  Scarborough                                Woburn  43.770992
# 4         M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
#Write data to a CSV file -- comment as required
#neighbourhoods.to_csv('Neighbourhood_data.csv')

# %% [markdown]
# #### Create a map of Toronto with neighborhoods superimposed on top.

# %%
#Get the central lats and longs for Toronto
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude, longitude])
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add neighbourhood markers to map
for lat, lng, bor, nhood in zip(neighbourhoods['Latitude'], neighbourhoods['Longitude'], neighbourhoods['Borough'], neighbourhoods['Neighbourhood']):
    label = '{}, {}'.format(nhood, bor)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Going to explore the Scarborough Bourough in the following analysis

# %%
scarborough_data = neighbourhoods[neighbourhoods['Borough'] == 'Scarborough'].reset_index(drop=True)
scarborough_data.head()
# Out:
#   Postal Code      Borough                         Neighbourhood   Latitude  \
# 0         M1B  Scarborough                         Rouge,Malvern  43.806686
# 1         M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2         M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3         M1G  Scarborough                                Woburn  43.770992
# 4         M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# #### Get the Lats and longs of the Scarborough borough

# %%
address = 'Scarborough, Ontario'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Scarborough are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Scarborough are 43.773077, -79.257774.

# %%
# create map of Scarborough using latitude and longitude values
map_scarborough = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(scarborough_data['Latitude'], scarborough_data['Longitude'], scarborough_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_scarborough)  
    
map_scarborough
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Use the FourSquare API to get venue data for the Toronto neighbourhoods

# %% [markdown]
# ##### Define Foursquare credentials

# %%
CLIENT_ID = 'FQK1QA11AK1OPXWQ1X1D4AVU1UKV1OV1SNOSJ04VVQJJGVHZ' # your Foursquare ID
CLIENT_SECRET = 'PWBEB4JGCJVP0XAFQ33YRC43ZMZIWXANE4LTCZ42XQNZRYYP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FQK1QA11AK1OPXWQ1X1D4AVU1UKV1OV1SNOSJ04VVQJJGVHZ
# CLIENT_SECRET:PWBEB4JGCJVP0XAFQ33YRC43ZMZIWXANE4LTCZ42XQNZRYYP

# %% [markdown]
# ##### Define function that will retrieve venue data for a neighbourhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=750):
    
    LIMIT = 100
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
scarborough_venues = getNearbyVenues(names=scarborough_data['Neighbourhood'],
                                   latitudes=scarborough_data['Latitude'],
                                   longitudes=scarborough_data['Longitude']
                                  )
# Out:
# Rouge,Malvern
# Highland Creek,Rouge Hill,Port Union
# Guildwood,Morningside,West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park,Ionview,Kennedy Park
# Clairlea,Golden Mile,Oakridge
# Cliffcrest,Cliffside,Scarborough Village West
# Birch Cliff,Cliffside West
# Dorset Park,Scarborough Town Centre,Wexford Heights
# Maryvale,Wexford
# Agincourt
# Clarks Corners,Sullivan,Tam O'Shanter
# Agincourt North,L'Amoreaux East,Milliken,Steeles East
# L'Amoreaux West
# Upper Rouge

# %%
#Have a look at the data
print(scarborough_venues.shape)
scarborough_venues
# Out:
# (205, 7)
#        Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0      Rouge,Malvern               43.806686               -79.194353
# 1      Rouge,Malvern               43.806686               -79.194353
# 2      Rouge,Malvern               43.806686               -79.194353
# 3      Rouge,Malvern               43.806686               -79.194353
# 4      Rouge,Malvern               43.806686               -79.194353
# ..               ...                     ...                      ...
# 200  L'Amoreaux West               43.799525               -79.318389
# 201  L'Amoreaux West               43.799525               -79.318389
# 202  L'Amoreaux West               43.799525               -79.318389
# 203  L'Amoreaux West               43.799525               -79.318389
# 204  L'Amoreaux West               43.799525               -79.318389
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 0           Images Salon & Spa       43.802283       -79.198565
# 1                      Wendy's       43.807448       -79.199056
# 2                      Wendy's       43.802008       -79.198080
# 3          Staples Morningside       43.800285       -79.196607
# 4                  Tim Hortons       43.802000       -79.198169
# ..                         ...             ...              ...
# 200              A Buck or Two       43.798286       -79.318485
# 201                Coffee Time       43.797952       -79.318678
# 202                   Presotea       43.799397       -79.319014
# 203                Warden Park       43.804789       -79.320449
# 204  CARSTAR Toronto St. Clair       43.803910       -79.313390
#
#                     Venue Category
# 0                              Spa
# 1             Fast Food Restaurant
# 2             Fast Food Restaurant
# 3    Paper / Office Supplies Store
# 4                      Coffee Shop
# ..                             ...
# 200         Thrift / Vintage Store
# 201                    Coffee Shop
# 202                Bubble Tea Shop
# 203           Other Great Outdoors
# 204                    Auto Garage
#
# [205 rows x 7 columns]

# %% [markdown]
# #### Check how many venues were returned for each neighborhood

# %%
scarborough_venues.groupby('Neighbourhood').count()
# Out:
#                                                     Neighbourhood Latitude  \
# Neighbourhood
# Agincourt                                                               14
# Agincourt North,L'Amoreaux East,Milliken,Steele...                      18
# Birch Cliff,Cliffside West                                               7
# Cedarbrae                                                               22
# Clairlea,Golden Mile,Oakridge                                           16
# Clarks Corners,Sullivan,Tam O'Shanter                                   20
# Cliffcrest,Cliffside,Scarborough Village West                            5
# Dorset Park,Scarborough Town Centre,Wexford Hei...                      15
# East Birchmount Park,Ionview,Kennedy Park                               16
# Guildwood,Morningside,West Hill                                         11
# Highland Creek,Rouge Hill,Port Union                                     5
# L'Amoreaux West                                                         15
# Maryvale,Wexford                                                        18
# Rouge,Malvern                                                            8
# Scarborough Village                                                      9
# Woburn                                                                   6
#
#                                                     Neighbourhood Longitude  \
# Neighbourhood
# Agincourt                                                                14
# Agincourt North,L'Amoreaux East,Milliken,Steele...                       18
# Birch Cliff,Cliffside West                                                7
# Cedarbrae                                                                22
# Clairlea,Golden Mile,Oakridge                                            16
# Clarks Corners,Sullivan,Tam O'Shanter                                    20
# Cliffcrest,Cliffside,Scarborough Village West                             5
# Dorset Park,Scarborough Town Centre,Wexford Hei...                       15
# East Birchmount Park,Ionview,Kennedy Park                                16
# Guildwood,Morningside,West Hill                                          11
# Highland Creek,Rouge Hill,Port Union                                      5
# L'Amoreaux West                                                          15
# Maryvale,Wexford                                                         18
# Rouge,Malvern                                                             8
# Scarborough Village                                                       9
# Woburn                                                                    6
#
#                                                     Venue  Venue Latitude  \
# Neighbourhood
# Agincourt                                              14              14
# Agincourt North,L'Amoreaux East,Milliken,Steele...     18              18
# Birch Cliff,Cliffside West                              7               7
# Cedarbrae                                              22              22
# Clairlea,Golden Mile,Oakridge                          16              16
# Clarks Corners,Sullivan,Tam O'Shanter                  20              20
# Cliffcrest,Cliffside,Scarborough Village West           5               5
# Dorset Park,Scarborough Town Centre,Wexford Hei...     15              15
# East Birchmount Park,Ionview,Kennedy Park              16              16
# Guildwood,Morningside,West Hill                        11              11
# Highland Creek,Rouge Hill,Port Union                    5               5
# L'Amoreaux West                                        15              15
# Maryvale,Wexford                                       18              18
# Rouge,Malvern                                           8               8
# Scarborough Village                                     9               9
# Woburn                                                  6               6
#
#                                                     Venue Longitude  \
# Neighbourhood
# Agincourt                                                        14
# Agincourt North,L'Amoreaux East,Milliken,Steele...               18
# Birch Cliff,Cliffside West                                        7
# Cedarbrae                                                        22
# Clairlea,Golden Mile,Oakridge                                    16
# Clarks Corners,Sullivan,Tam O'Shanter                            20
# Cliffcrest,Cliffside,Scarborough Village West                     5
# Dorset Park,Scarborough Town Centre,Wexford Hei...               15
# East Birchmount Park,Ionview,Kennedy Park                        16
# Guildwood,Morningside,West Hill                                  11
# Highland Creek,Rouge Hill,Port Union                              5
# L'Amoreaux West                                                  15
# Maryvale,Wexford                                                 18
# Rouge,Malvern                                                     8
# Scarborough Village                                               9
# Woburn                                                            6
#
#                                                     Venue Category
# Neighbourhood
# Agincourt                                                       14
# Agincourt North,L'Amoreaux East,Milliken,Steele...              18
# Birch Cliff,Cliffside West                                       7
# Cedarbrae                                                       22
# Clairlea,Golden Mile,Oakridge                                   16
# Clarks Corners,Sullivan,Tam O'Shanter                           20
# Cliffcrest,Cliffside,Scarborough Village West                    5
# Dorset Park,Scarborough Town Centre,Wexford Hei...              15
# East Birchmount Park,Ionview,Kennedy Park                       16
# Guildwood,Morningside,West Hill                                 11
# Highland Creek,Rouge Hill,Port Union                             5
# L'Amoreaux West                                                 15
# Maryvale,Wexford                                                18
# Rouge,Malvern                                                    8
# Scarborough Village                                              9
# Woburn                                                           6

# %% [markdown]
# #### Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} unique categories.'.format(len(scarborough_venues['Venue Category'].unique())))
# Out:
# There are 85 unique categories.

# %% [markdown]
# #### Analyse each neighbourhood

# %%
# one hot encoding
scarborough_onehot = pd.get_dummies(scarborough_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighbourhood column back to dataframe
scarborough_onehot['Neighbourhood'] = scarborough_venues['Neighbourhood'] 

# move neighbourhood column to the first column
fixed_columns = [scarborough_onehot.columns[-1]] + list(scarborough_onehot.columns[:-1])
scarborough_onehot = scarborough_onehot[fixed_columns]

scarborough_onehot.tail()
# Out:
#        Neighbourhood  African Restaurant  American Restaurant  \
# 200  L'Amoreaux West                   0                    0
# 201  L'Amoreaux West                   0                    0
# 202  L'Amoreaux West                   0                    0
# 203  L'Amoreaux West                   0                    0
# 204  L'Amoreaux West                   0                    0
#
#      Asian Restaurant  Athletics & Sports  Auto Garage  BBQ Joint  \
# 200                 0                   0            0          0
# 201                 0                   0            0          0
# 202                 0                   0            0          0
# 203                 0                   0            0          0
# 204                 0                   0            1          0
#
#      Badminton Court  Bakery  Bank  ...  Spa  Sports Bar  Supermarket  \
# 200                0       0     0  ...    0           0            0
# 201                0       0     0  ...    0           0            0
# 202                0       0     0  ...    0           0            0
# 203                0       0     0  ...    0           0            0
# 204                0       0     0  ...    0           0            0
#
#      Sushi Restaurant  Thai Restaurant  Thrift / Vintage Store  \
# 200                 0                0                       1
# 201                 0                0                       0
# 202                 0                0                       0
# 203                 0                0                       0
# 204                 0                0                       0
#
#      Vietnamese Restaurant  Wings Joint  Women's Store  Yoga Studio
# 200                      0            0              0            0
# 201                      0            0              0            0
# 202                      0            0              0            0
# 203                      0            0              0            0
# 204                      0            0              0            0
#
# [5 rows x 86 columns]

# %%
scarborough_onehot.shape
# Out:
# (205, 86)

# %% [markdown]
# #### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
scarborough_grouped = scarborough_onehot.groupby('Neighbourhood').mean().reset_index()
scarborough_grouped
# Out:
#                                         Neighbourhood  African Restaurant  \
# 0                                           Agincourt               0.000
# 1   Agincourt North,L'Amoreaux East,Milliken,Steel...               0.000
# 2                          Birch Cliff,Cliffside West               0.000
# 3                                           Cedarbrae               0.000
# 4                       Clairlea,Golden Mile,Oakridge               0.000
# 5               Clarks Corners,Sullivan,Tam O'Shanter               0.000
# 6       Cliffcrest,Cliffside,Scarborough Village West               0.000
# 7   Dorset Park,Scarborough Town Centre,Wexford He...               0.000
# 8           East Birchmount Park,Ionview,Kennedy Park               0.000
# 9                     Guildwood,Morningside,West Hill               0.000
# 10               Highland Creek,Rouge Hill,Port Union               0.000
# 11                                    L'Amoreaux West               0.000
# 12                                   Maryvale,Wexford               0.000
# 13                                      Rouge,Malvern               0.125
# 14                                Scarborough Village               0.000
# 15                                             Woburn               0.000
#
#     American Restaurant  Asian Restaurant  Athletics & Sports  Auto Garage  \
# 0              0.071429          0.000000            0.000000     0.000000
# 1              0.000000          0.000000            0.000000     0.000000
# 2              0.000000          0.000000            0.000000     0.000000
# 3              0.000000          0.045455            0.045455     0.000000
# 4              0.000000          0.000000            0.000000     0.000000
# 5              0.000000          0.000000            0.000000     0.000000
# 6              0.000000          0.000000            0.000000     0.000000
# 7              0.000000          0.000000            0.000000     0.000000
# 8              0.000000          0.000000            0.000000     0.000000
# 9              0.000000          0.000000            0.000000     0.000000
# 10             0.000000          0.000000            0.000000     0.000000
# 11             0.000000          0.000000            0.000000     0.066667
# 12             0.000000          0.000000            0.000000     0.000000
# 13             0.000000          0.000000            0.000000     0.000000
# 14             0.000000          0.000000            0.000000     0.000000
# 15             0.000000          0.000000            0.000000     0.000000
#
#     BBQ Joint  Badminton Court    Bakery      Bank  ...       Spa  Sports Bar  \
# 0    0.000000         0.071429  0.000000  0.000000  ...  0.000000    0.000000
# 1    0.055556         0.000000  0.000000  0.000000  ...  0.000000    0.000000
# 2    0.000000         0.000000  0.000000  0.142857  ...  0.000000    0.000000
# 3    0.000000         0.000000  0.090909  0.045455  ...  0.000000    0.000000
# 4    0.000000         0.000000  0.125000  0.000000  ...  0.000000    0.000000
# 5    0.000000         0.000000  0.000000  0.050000  ...  0.000000    0.000000
# 6    0.000000         0.000000  0.000000  0.000000  ...  0.000000    0.000000
# 7    0.000000         0.000000  0.066667  0.000000  ...  0.066667    0.000000
# 8    0.000000         0.000000  0.000000  0.062500  ...  0.000000    0.000000
# 9    0.000000         0.000000  0.000000  0.000000  ...  0.000000    0.090909
# 10   0.000000         0.000000  0.000000  0.000000  ...  0.000000    0.000000
# 11   0.000000         0.000000  0.000000  0.000000  ...  0.000000    0.000000
# 12   0.000000         0.000000  0.000000  0.000000  ...  0.000000    0.000000
# 13   0.000000         0.000000  0.000000  0.000000  ...  0.125000    0.000000
# 14   0.000000         0.000000  0.000000  0.000000  ...  0.000000    0.000000
# 15   0.000000         0.000000  0.000000  0.000000  ...  0.000000    0.000000
#
#     Supermarket  Sushi Restaurant  Thai Restaurant  Thrift / Vintage Store  \
# 0      0.071429          0.071429         0.000000                0.000000
# 1      0.000000          0.000000         0.000000                0.000000
# 2      0.000000          0.000000         0.142857                0.000000
# 3      0.000000          0.000000         0.045455                0.000000
# 4      0.000000          0.000000         0.000000                0.000000
# 5      0.000000          0.000000         0.050000                0.000000
# 6      0.000000          0.000000         0.000000                0.000000
# 7      0.000000          0.000000         0.000000                0.000000
# 8      0.000000          0.000000         0.000000                0.000000
# 9      0.000000          0.000000         0.000000                0.090909
# 10     0.000000          0.000000         0.000000                0.000000
# 11     0.000000          0.000000         0.000000                0.066667
# 12     0.000000          0.000000         0.000000                0.000000
# 13     0.000000          0.000000         0.000000                0.000000
# 14     0.000000          0.000000         0.000000                0.000000
# 15     0.000000          0.000000         0.000000                0.000000
#
#     Vietnamese Restaurant  Wings Joint  Women's Store  Yoga Studio
# 0                0.000000     0.000000       0.000000     0.000000
# 1                0.000000     0.000000       0.000000     0.000000
# 2                0.000000     0.000000       0.000000     0.000000
# 3                0.000000     0.000000       0.000000     0.045455
# 4                0.000000     0.000000       0.000000     0.000000
# 5                0.000000     0.000000       0.000000     0.000000
# 6                0.000000     0.200000       0.000000     0.000000
# 7                0.066667     0.066667       0.000000     0.000000
# 8                0.000000     0.000000       0.000000     0.000000
# 9                0.000000     0.000000       0.000000     0.000000
# 10               0.000000     0.000000       0.000000     0.000000
# 11               0.000000     0.000000       0.000000     0.000000
# 12               0.055556     0.000000       0.000000     0.000000
# 13               0.000000     0.000000       0.000000     0.000000
# 14               0.000000     0.000000       0.111111     0.000000
# 15               0.000000     0.000000       0.000000     0.000000
#
# [16 rows x 86 columns]

# %% [markdown]
# #### Let's print each neighbourhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in scarborough_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = scarborough_grouped[scarborough_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                       venue  freq
# 0  Mediterranean Restaurant  0.07
# 1                    Lounge  0.07
# 2                 Pool Hall  0.07
# 3            Sandwich Place  0.07
# 4        Seafood Restaurant  0.07
#
#
# ----Agincourt North,L'Amoreaux East,Milliken,Steeles East----
#                   venue  freq
# 0           Pizza Place  0.11
# 1    Chinese Restaurant  0.11
# 2     Korean Restaurant  0.06
# 3  Fast Food Restaurant  0.06
# 4                  Park  0.06
#
#
# ----Birch Cliff,Cliffside West----
#              venue  freq
# 0  College Stadium  0.14
# 1  Thai Restaurant  0.14
# 2             Café  0.14
# 3     Skating Rink  0.14
# 4            Diner  0.14
#
#
# ----Cedarbrae----
#                venue  freq
# 0           Pharmacy  0.09
# 1        Coffee Shop  0.09
# 2  Indian Restaurant  0.09
# 3             Bakery  0.09
# 4        Yoga Studio  0.05
#
#
# ----Clairlea,Golden Mile,Oakridge----
#           venue  freq
# 0  Intersection  0.19
# 1         Diner  0.12
# 2   Coffee Shop  0.12
# 3        Bakery  0.12
# 4      Bus Line  0.12
#
#
# ----Clarks Corners,Sullivan,Tam O'Shanter----
#                   venue  freq
# 0           Pizza Place  0.10
# 1          Noodle House  0.05
# 2  Fast Food Restaurant  0.05
# 3   Fried Chicken Joint  0.05
# 4     Convenience Store  0.05
#
#
# ----Cliffcrest,Cliffside,Scarborough Village West----
#                 venue  freq
# 0      Hardware Store   0.2
# 1        Burger Joint   0.2
# 2  Chinese Restaurant   0.2
# 3         Pizza Place   0.2
# 4         Wings Joint   0.2
#
#
# ----Dorset Park,Scarborough Town Centre,Wexford Heights----
#                        venue  freq
# 0          Indian Restaurant  0.13
# 1          Electronics Store  0.13
# 2     Furniture / Home Store  0.07
# 3      Vietnamese Restaurant  0.07
# 4  Latin American Restaurant  0.07
#
#
# ----East Birchmount Park,Ionview,Kennedy Park----
#                venue  freq
# 0        Coffee Shop  0.19
# 1     Discount Store  0.12
# 2  Convenience Store  0.06
# 3        Bus Station  0.06
# 4         Hobby Shop  0.06
#
#
# ----Guildwood,Morningside,West Hill----
#                     venue  freq
# 0             Pizza Place  0.18
# 1    Fast Food Restaurant  0.18
# 2             Coffee Shop  0.09
# 3  Thrift / Vintage Store  0.09
# 4           Grocery Store  0.09
#
#
# ----Highland Creek,Rouge Hill,Port Union----
#                 venue  freq
# 0      Breakfast Spot   0.4
# 1        Burger Joint   0.2
# 2  Italian Restaurant   0.2
# 3                 Bar   0.2
# 4            Pharmacy   0.0
#
#
# ----L'Amoreaux West----
#                   venue  freq
# 0  Fast Food Restaurant  0.13
# 1           Coffee Shop  0.13
# 2    Chinese Restaurant  0.13
# 3              Pharmacy  0.07
# 4           Auto Garage  0.07
#
#
# ----Maryvale,Wexford----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.11
# 1                Pizza Place  0.11
# 2               Burger Joint  0.11
# 3             Breakfast Spot  0.06
# 4                 Print Shop  0.06
#
#
# ----Rouge,Malvern----
#                            venue  freq
# 0           Fast Food Restaurant  0.25
# 1             African Restaurant  0.12
# 2                            Spa  0.12
# 3  Paper / Office Supplies Store  0.12
# 4                    Coffee Shop  0.12
#
#
# ----Scarborough Village----
#                   venue  freq
# 0  Fast Food Restaurant  0.33
# 1           Pizza Place  0.11
# 2         Women's Store  0.11
# 3     Convenience Store  0.11
# 4           Coffee Shop  0.11
#
#
# ----Woburn----
#                 venue  freq
# 0         Coffee Shop  0.33
# 1                Park  0.33
# 2    Business Service  0.17
# 3   Convenience Store  0.17
# 4  African Restaurant  0.00

# %% [markdown]
# #### Let's put that into a *pandas* dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# #### Now let's create the new dataframe and display the top 10 venues for each neighbourhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = scarborough_grouped['Neighbourhood']

for ind in np.arange(scarborough_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(scarborough_grouped.iloc[ind, :], num_top_venues)

neighbourhoods_venues_sorted.tail()
# Out:
#           Neighbourhood      1st Most Common Venue 2nd Most Common Venue  \
# 11      L'Amoreaux West       Fast Food Restaurant           Coffee Shop
# 12     Maryvale,Wexford  Middle Eastern Restaurant           Pizza Place
# 13        Rouge,Malvern       Fast Food Restaurant    African Restaurant
# 14  Scarborough Village       Fast Food Restaurant           Coffee Shop
# 15               Woburn                Coffee Shop                  Park
#
#             3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11             Chinese Restaurant              Pharmacy        Breakfast Spot
# 12                   Burger Joint         Grocery Store                   Bar
# 13  Paper / Office Supplies Store            Hobby Shop           Bus Station
# 14                  Women's Store           Pizza Place     Convenience Store
# 15              Convenience Store      Business Service           Yoga Studio
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 11  Other Great Outdoors           Pizza Place        Sandwich Place
# 12            Print Shop            Restaurant    Seafood Restaurant
# 13                   Spa           Coffee Shop           Fish Market
# 14            Restaurant        Sandwich Place       College Stadium
# 15      Department Store                 Diner        Discount Store
#
#    9th Most Common Venue 10th Most Common Venue
# 11       Bubble Tea Shop          Grocery Store
# 12        Breakfast Spot            Fish Market
# 13     Convenience Store       Department Store
# 14      Department Store                  Diner
# 15     Electronics Store   Fast Food Restaurant

# %% [markdown]
# ### Cluster Neighbourhoods

# %% [markdown]
# Run *k*-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

scarborough_grouped_clustering = scarborough_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(scarborough_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:5]
# Out:
# array([3, 0, 3, 3, 3], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighbourhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

scarborough_merged = scarborough_data

# merge scarborough_grouped with scarborough_data to add latitude/longitude for each neighborhood
scarborough_merged = scarborough_merged.join(neighbourhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

scarborough_merged.tail() # check the last columns!
# Out:
#    Postal Code      Borough  \
# 12         M1S  Scarborough
# 13         M1T  Scarborough
# 14         M1V  Scarborough
# 15         M1W  Scarborough
# 16         M1X  Scarborough
#
#                                         Neighbourhood   Latitude  Longitude  \
# 12                                          Agincourt  43.794200 -79.262029
# 13              Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14  Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                    L'Amoreaux West  43.799525 -79.318389
# 16                                        Upper Rouge  43.836125 -79.205636
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 12             3.0   Shanghai Restaurant        Breakfast Spot
# 13             0.0           Pizza Place              Bus Stop
# 14             0.0    Chinese Restaurant           Pizza Place
# 15             0.0  Fast Food Restaurant           Coffee Shop
# 16             NaN                   NaN                   NaN
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 12        Sandwich Place    Seafood Restaurant        Discount Store
# 13         Shopping Mall          Noodle House     Convenience Store
# 14  Caribbean Restaurant     Korean Restaurant                  Park
# 15    Chinese Restaurant              Pharmacy        Breakfast Spot
# 16                   NaN                   NaN                   NaN
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 12         Shopping Mall          Skating Rink       Badminton Court
# 13           Golf Course              Pharmacy  Fast Food Restaurant
# 14              Pharmacy      Malay Restaurant  Fast Food Restaurant
# 15  Other Great Outdoors           Pizza Place        Sandwich Place
# 16                   NaN                   NaN                   NaN
#
#    9th Most Common Venue 10th Most Common Venue
# 12           Supermarket       Sushi Restaurant
# 13        Sandwich Place     Seafood Restaurant
# 14          Noodle House         Shop & Service
# 15       Bubble Tea Shop          Grocery Store
# 16                   NaN                    NaN

# %%
#The data shows that Scarborough Upper Rouge did not return any venues therefore data contains NaN, will delete this row from
#the data
scarborough_merged = scarborough_merged.drop(scarborough_merged[scarborough_merged['Neighbourhood'] == 'Upper Rouge'].index)
scarborough_merged['Cluster Labels']= scarborough_merged['Cluster Labels'].astype('int32')

# %%
scarborough_merged.tail()
# Out:
#    Postal Code      Borough  \
# 11         M1R  Scarborough
# 12         M1S  Scarborough
# 13         M1T  Scarborough
# 14         M1V  Scarborough
# 15         M1W  Scarborough
#
#                                         Neighbourhood   Latitude  Longitude  \
# 11                                   Maryvale,Wexford  43.750072 -79.295849
# 12                                          Agincourt  43.794200 -79.262029
# 13              Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14  Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                    L'Amoreaux West  43.799525 -79.318389
#
#     Cluster Labels      1st Most Common Venue 2nd Most Common Venue  \
# 11               0  Middle Eastern Restaurant           Pizza Place
# 12               3        Shanghai Restaurant        Breakfast Spot
# 13               0                Pizza Place              Bus Stop
# 14               0         Chinese Restaurant           Pizza Place
# 15               0       Fast Food Restaurant           Coffee Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11          Burger Joint         Grocery Store                   Bar
# 12        Sandwich Place    Seafood Restaurant        Discount Store
# 13         Shopping Mall          Noodle House     Convenience Store
# 14  Caribbean Restaurant     Korean Restaurant                  Park
# 15    Chinese Restaurant              Pharmacy        Breakfast Spot
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 11            Print Shop            Restaurant    Seafood Restaurant
# 12         Shopping Mall          Skating Rink       Badminton Court
# 13           Golf Course              Pharmacy  Fast Food Restaurant
# 14              Pharmacy      Malay Restaurant  Fast Food Restaurant
# 15  Other Great Outdoors           Pizza Place        Sandwich Place
#
#    9th Most Common Venue 10th Most Common Venue
# 11        Breakfast Spot            Fish Market
# 12           Supermarket       Sushi Restaurant
# 13        Sandwich Place     Seafood Restaurant
# 14          Noodle House         Shop & Service
# 15       Bubble Tea Shop          Grocery Store

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(scarborough_merged['Latitude'], scarborough_merged['Longitude'], scarborough_merged['Neighbourhood'], scarborough_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Closer look at the cluster data

# %% [markdown]
# #### Cluster 1

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 0, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels      1st Most Common Venue  \
# 0   Scarborough               0       Fast Food Restaurant
# 2   Scarborough               0       Fast Food Restaurant
# 5   Scarborough               0       Fast Food Restaurant
# 11  Scarborough               0  Middle Eastern Restaurant
# 13  Scarborough               0                Pizza Place
# 14  Scarborough               0         Chinese Restaurant
# 15  Scarborough               0       Fast Food Restaurant
#
#    2nd Most Common Venue          3rd Most Common Venue 4th Most Common Venue  \
# 0     African Restaurant  Paper / Office Supplies Store            Hobby Shop
# 2            Pizza Place                    Coffee Shop         Grocery Store
# 5            Coffee Shop                  Women's Store           Pizza Place
# 11           Pizza Place                   Burger Joint         Grocery Store
# 13              Bus Stop                  Shopping Mall          Noodle House
# 14           Pizza Place           Caribbean Restaurant     Korean Restaurant
# 15           Coffee Shop             Chinese Restaurant              Pharmacy
#
#    5th Most Common Venue   6th Most Common Venue 7th Most Common Venue  \
# 0            Bus Station                     Spa           Coffee Shop
# 2       Greek Restaurant  Thrift / Vintage Store            Sports Bar
# 5      Convenience Store              Restaurant        Sandwich Place
# 11                   Bar              Print Shop            Restaurant
# 13     Convenience Store             Golf Course              Pharmacy
# 14                  Park                Pharmacy      Malay Restaurant
# 15        Breakfast Spot    Other Great Outdoors           Pizza Place
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0            Fish Market     Convenience Store       Department Store
# 2    Fried Chicken Joint            Beer Store        College Stadium
# 5        College Stadium      Department Store                  Diner
# 11    Seafood Restaurant        Breakfast Spot            Fish Market
# 13  Fast Food Restaurant        Sandwich Place     Seafood Restaurant
# 14  Fast Food Restaurant          Noodle House         Shop & Service
# 15        Sandwich Place       Bubble Tea Shop          Grocery Store

# %% [markdown]
# Good areas to eat out, especially pizza, fast food and Asian food.

# %% [markdown]
# #### Cluster 2

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 1, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3  Scarborough               1           Coffee Shop                  Park
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 3     Convenience Store      Business Service           Yoga Studio
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 3      Department Store                 Diner        Discount Store
#
#   9th Most Common Venue 10th Most Common Venue
# 3     Electronics Store   Fast Food Restaurant

# %% [markdown]
# Coffee shops and parks, more laid back.

# %% [markdown]
# #### Cluster 3

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 2, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1  Scarborough               2        Breakfast Spot    Italian Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1                   Bar          Burger Joint           Yoga Studio
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1            Food Court      Department Store                 Diner
#
#   9th Most Common Venue 10th Most Common Venue
# 1        Discount Store      Electronics Store

# %% [markdown]
# Mix of food

# %% [markdown]
# #### Cluster 4

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 3, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 4   Scarborough               3              Pharmacy      Indian Restaurant
# 6   Scarborough               3           Coffee Shop         Discount Store
# 7   Scarborough               3          Intersection            Coffee Shop
# 9   Scarborough               3                  Café  General Entertainment
# 10  Scarborough               3     Indian Restaurant      Electronics Store
# 12  Scarborough               3   Shanghai Restaurant         Breakfast Spot
#
#    3rd Most Common Venue 4th Most Common Venue   5th Most Common Venue  \
# 4            Coffee Shop                Bakery            Burger Joint
# 6               Pharmacy     Convenience Store           Grocery Store
# 7                  Diner                Bakery                Bus Line
# 9        College Stadium                 Diner                    Bank
# 10             Pet Store                Bakery  Furniture / Home Store
# 12        Sandwich Place    Seafood Restaurant          Discount Store
#
#         6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 4            Hakka Restaurant   Fried Chicken Joint           Flower Shop
# 6            Department Store   Rental Car Location           Bus Station
# 7        Fast Food Restaurant     Convenience Store         Metro Station
# 9                Skating Rink       Thai Restaurant  Fast Food Restaurant
# 10  Latin American Restaurant  Fast Food Restaurant           Coffee Shop
# 12              Shopping Mall          Skating Rink       Badminton Court
#
#    9th Most Common Venue 10th Most Common Venue
# 4            Music Store     Chinese Restaurant
# 6         Sandwich Place     Light Rail Station
# 7           Soccer Field                   Park
# 9          Grocery Store      Convenience Store
# 10    Chinese Restaurant                    Gym
# 12           Supermarket       Sushi Restaurant

# %% [markdown]
# Shopping and entertainment areas.

# %% [markdown]
# #### Cluster 5

# %%
scarborough_merged.loc[scarborough_merged['Cluster Labels'] == 4, scarborough_merged.columns[[1] + list(range(5, scarborough_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 8  Scarborough               4        Hardware Store          Burger Joint
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 8    Chinese Restaurant           Pizza Place           Wings Joint
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 8           Flower Shop     Convenience Store      Department Store
#
#   9th Most Common Venue 10th Most Common Venue
# 8                 Diner         Discount Store
