# %% [markdown]
# # Assignment Week 5 Capstone Data Science

# %% [markdown]
# ### Business Problem

# %% [markdown]
# The client, Mr Roy, would like to start up an Indian Restaurant in one of the London Boroughs. He currently owns two successful restaurants in Birmingham but is unfamiliar with the London Boroughs and which one would be best suited to set up his third restaurant.
#
# Mr Roy’s restaurant would be opened 7 days a week in the evening only and ideally, he would like there to be passing trade from people enjoying an evening out. Mr Roy’s restaurant would also provide a take-away service and he would offer free delivery within a 3-mile radius.
#
# Mr Roy would like to understand the make-up of the London boroughs and would like a recommendation on which ones best meet his criteria. Areas with evening entertainment but also a good residential area to requiring a take-away service.

# %% [markdown]
# ### Data Description

# %% [markdown]
# The following wiki page will be used to obtain the London Boroughs, the geo data and populations.
#
# https://en.wikipedia.org/wiki/List_of_London_boroughs
#
# The following CSV document shows the business success for each of the London Boroughs. This can be merged with the wiki data to give a further factor for later analysis. The 5-year survival will be used.
#
# https://data.london.gov.uk/dataset/business-demographics-and-survival-rates-borough
#
# Downloaded data: Business Survival Rate (CSV)
#
# The Foursquare API will be used to show venue categories for the London Boroughs. The London Borough central geo data will be used as the central search point. As the boroughs differ in size considerably, the search radius will be calculated as the square root of the borough area and converted the figure to metres.
#
# Using K-means, the venue categories for the different London boroughs will be clustered. The clusters can then be interpreted and summarised. The most suitable areas can then be presented to Mr. Roy.

# %% [markdown]
# #### Import libraries required for assignment

# %%
#Required to open URL
import requests

#Install BeautifulSoup - comment out else when done
# !conda install -c conda-forge beautifulsoup4 --yes
from bs4 import BeautifulSoup

#Pandas library
import pandas as pd

#Install geocoder - comment out else when done
# !conda install -c conda-forge geocoder --yes
import geocoder

#Install geopy - comment out else when done
# !conda install -c conda-forge geopy --yes
import folium
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import json # library to handle JSON files
# import k-means from clustering stage
from sklearn.cluster import KMeans
from pandas.io.json import json_normalize

import numpy as np # library to handle data in a vectorized manner

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     soupsieve-1.9.4            |           py36_0          58 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     beautifulsoup4-4.8.0       |           py36_0         144 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         348 KB
#
# The following NEW packages will be INSTALLED:
#
#     soupsieve:      1.9.4-py36_0     conda-forge
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.3-py37_0                 --> 4.8.0-py36_0     conda-forge
#     certifi:        2019.6.16-py36_1 conda-forge --> 2019.9.11-py36_0 conda-forge
#
#
# Downloading and Extracting Packages
# soupsieve-1.9.4      | 58 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# beautifulsoup4-4.8.0 | 144 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     click-7.0                  |             py_0          61 KB  conda-forge
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     future-0.17.1              |        py36_1000         701 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         821 KB
#
# The following NEW packages will be INSTALLED:
#
#     future:   0.17.1-py36_1000 conda-forge
#     geocoder: 1.38.1-py_1      conda-forge
#     ratelim:  0.1.6-py_2       conda-forge
#
# The following packages will be UPDATED:
#
#     click:    6.7-py37_0                   --> 7.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# click-7.0            | 61 KB     | ##################################### | 100%
# ratelim-0.1.6        | 6 KB      | ##################################### | 100%
# geocoder-1.38.1      | 53 KB     | ##################################### | 100%
# future-0.17.1        | 701 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          91 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ### First stage is to scrape the wiki page for the data and format data into a data frame.

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_London_boroughs').text

# %% [markdown]
# #### Parse the HTML of the URL into a Beautiful Soup tree

# %%
soup = BeautifulSoup(website_url)

# %%
#Find the title
soup.title
# Out:
# <title>List of London boroughs - Wikipedia</title>

# %% [markdown]
# #### Bring back the table using find

# %%
pcode_table=soup.find('table', class_='wikitable sortable')
#pcode_table

# %% [markdown]
# #### Each row in the table is starts with "tr" and the data within is row is within "td".

# %% [markdown]
# Loop through the pcode table and find the "tr" then the "td" tags. If the row has 3 columns then store the data in lists A (first column), B (second column) and C(third column).

# %%
A=[]
G=[]
K=[]


for row in pcode_table.findAll('tr'):
    cells=row.findAll('td')
    subcells=row.findAll('span')
    if len(cells)==10:
        A.append(cells[0].find(text=True))
        K.append(cells[6].find(text=True))
        G.append(subcells[7].find(text=True))

# %%
#Have a quick check of the data
print(A)
# Out:
# ['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']

# %%
print(K)
# Out:
# ['13.93\n', '33.49\n', '23.38\n', '16.70\n', '57.97\n', '8.40\n', '33.41\n', '21.44\n', '31.74\n', '18.28\n', '7.36\n', '6.33\n', '11.42\n', '19.49\n', '43.35\n', '44.67\n', '21.61\n', '5.74\n', '4.68\n', '14.38\n', '10.36\n', '13.57\n', '14.52\n', '13.98\n', '21.78\n', '22.17\n', '11.14\n', '16.93\n', '7.63\n', '14.99\n', '13.23\n', '8.29\n']

# %%
print(G)
# Out:
# ['51.5607°N 0.1557°E', '51.6252°N 0.1517°W', '51.4549°N 0.1505°E', '51.5588°N 0.2817°W', '51.4039°N 0.0198°E', '51.5290°N 0.1255°W', '51.3714°N 0.0977°W', '51.5130°N 0.3089°W', '51.6538°N 0.0799°W', '51.4892°N 0.0648°E', '51.5450°N 0.0553°W', '51.4927°N 0.2339°W', '51.6000°N 0.1119°W', '51.5898°N 0.3346°W', '51.5812°N 0.1837°E', '51.5441°N 0.4760°W', '51.4746°N 0.3680°W', '51.5416°N 0.1022°W', '51.5020°N 0.1947°W', '51.4085°N 0.3064°W', '51.4607°N 0.1163°W', '51.4452°N 0.0209°W', '51.4014°N 0.1958°W', '51.5077°N 0.0469°E', '51.5590°N 0.0741°E', '51.4479°N 0.3260°W', '51.5035°N 0.0804°W', '51.3618°N 0.1945°W', '51.5099°N 0.0059°W', '51.5908°N 0.0134°W', '51.4567°N 0.1910°W', '51.4973°N 0.1372°W']

# %% [markdown]
# #### There appears to be some newlines in the columns. Use rstrip to go through list and clean.

# %%
j=0
for i in A:
    A[j]=i.rstrip()
    j=j+1
j=0
for i in K:
    K[j]=i.rstrip()
    j=j+1
j=0
for i in G:
    G[j]=i.rstrip()
    j=j+1

# %% [markdown]
# #### Convert to dataframe and add columns headings

# %%
df=pd.DataFrame(A,columns=['Borough'])
df['Area']=K
df['Geo']=G

# %% [markdown]
# #### Check the top and bottom of the dataframe to ensure it's captured

# %%
df.head()
# Out:
#                 Borough   Area                 Geo
# 0  Barking and Dagenham  13.93  51.5607°N 0.1557°E
# 1                Barnet  33.49  51.6252°N 0.1517°W
# 2                Bexley  23.38  51.4549°N 0.1505°E
# 3                 Brent  16.70  51.5588°N 0.2817°W
# 4               Bromley  57.97  51.4039°N 0.0198°E

# %% [markdown]
# ##### Need to tidy the dataframe up

# %%
#Check the data types
df.dtypes
# Out:
# Borough    object
# Area       object
# Geo        object
# dtype: object

# %%
#Area needs to be converted to float
df['Area'] = df['Area'].astype('float64')
df.dtypes
# Out:
# Borough     object
# Area       float64
# Geo         object
# dtype: object

# %% [markdown]
# ##### Now need to sort the Geo data into the lats and longs

# %%
#Split Geo column by space and assign to a new dataframe
dfgeo= df['Geo'].str.split(' ',expand=True)

# %%
dfgeo.head()
# Out:
#            0         1
# 0  51.5607°N  0.1557°E
# 1  51.6252°N  0.1517°W
# 2  51.4549°N  0.1505°E
# 3  51.5588°N  0.2817°W
# 4  51.4039°N  0.0198°E

# %%
#Remove the degrees north
dfgeo[0]= dfgeo[0].str.split('°N',expand=True)
#Convert to float
dfgeo[0] = pd.to_numeric(dfgeo[0],errors='coerce')
#Rename Column 0
dfgeo.columns = ['Latitude','Longitude']

# %%
dfgeo.head()
# Out:
#    Latitude Longitude
# 0   51.5607  0.1557°E
# 1   51.6252  0.1517°W
# 2   51.4549  0.1505°E
# 3   51.5588  0.2817°W
# 4   51.4039  0.0198°E

# %%
#Process the longitude, split off the direction and convert to float and integer
dlong = dfgeo['Longitude'].str.split('°',expand=True)
dlong.columns = ['Longitude','Direction']

# %%
dlong.dtypes
# Out:
# Longitude    object
# Direction    object
# dtype: object

# %%
dlong['Longitude'] = pd.to_numeric(dlong['Longitude'],errors='coerce')
dlong['Direction'] = dlong['Direction'].str.replace('E', '1')
dlong['Direction'] = dlong['Direction'].str.replace('W', '-1')
dlong['Direction'] = pd.to_numeric(dlong['Direction'],errors='coerce')
dlong.dtypes
# Out:
# Longitude    float64
# Direction      int64
# dtype: object

# %%
#Process direction
dlong['Longitude'] = dlong['Direction'] * dlong['Longitude']

# %%
dfgeo['Longitude'] = dlong['Longitude']

# %%
#Drop the Geo column and add on the longitude and Latitude columns
df.drop(['Geo'], axis=1, inplace=True)
df['Latitude'] = dfgeo['Latitude']
df['Longitude'] = dfgeo['Longitude']

# %%
#Create a search radius column. Sq root (Area) and convert miles to metres.
df['Radius'] = df['Area']**(1/2)
df['Radius'] = (df['Radius']*1609.34) * 0.5

# %%
df.head()
# Out:
#                 Borough   Area  Latitude  Longitude       Radius
# 0  Barking and Dagenham  13.93   51.5607     0.1557  3003.263018
# 1                Barnet  33.49   51.6252    -0.1517  4656.669159
# 2                Bexley  23.38   51.4549     0.1505  3890.810359
# 3                 Brent  16.70   51.5588    -0.2817  3288.334930
# 4               Bromley  57.97   51.4039     0.0198  6126.599065

# %% [markdown]
# ##### Read in the business survival rates as a CSV

# %%
dfbus=pd.read_csv('business_survival_rates.csv')

# %%
dfbus.head()
# Out:
#         code                  area  year  births  1_year_survival_number  \
# 0  E09000001        City of London  2002    1145                    1025
# 1  E09000002  Barking and Dagenham  2002     435                     410
# 2  E09000003                Barnet  2002    2330                    2185
# 3  E09000004                Bexley  2002     765                     710
# 4  E09000005                 Brent  2002    1635                    1530
#
#    1_year_survival_rate 2_year_survival_number 2_year_survival_rate  \
# 0                  89.5                    915                 79.9
# 1                  94.3                    335                   77
# 2                  93.8                   1805                 77.5
# 3                  92.8                    595                 77.8
# 4                  93.6                   1135                 69.4
#
#   3_year_survival_number 3_year_survival_rate 4_year_survival_number  \
# 0                    760                 66.4                    660
# 1                    250                 57.5                    205
# 2                   1290                 55.4                   1030
# 3                    470                 61.4                    385
# 4                    810                 49.5                    625
#
#   4_year_survival_rate 5_year_survival_number 5_year_survival_rate
# 0                 57.6                    600                 52.4
# 1                 47.1                    175                 40.2
# 2                 44.2                    855                 36.7
# 3                 50.3                    325                 42.5
# 4                 38.2                    525                 32.1

# %%
#Rename area to Borough
dfbus.rename(columns={'area':'Borough'}, inplace=True)

# %%
#Select just the 2012 rows as this is the latest data
dfnew = dfbus[dfbus['year'] == 2012]

# %%
#Drop the unwanted columns
dfnew.drop(['code','year','births','1_year_survival_number','1_year_survival_rate','2_year_survival_number','2_year_survival_rate'], axis=1, inplace=True)
dfnew.drop(['3_year_survival_number','3_year_survival_rate','4_year_survival_number','4_year_survival_rate','5_year_survival_number'], axis=1, inplace=True)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dfnew.head()
# Out:
#                   Borough 5_year_survival_rate
# 510        City of London                 37.9
# 511  Barking and Dagenham                 39.6
# 512                Barnet                 40.9
# 513                Bexley                 44.1
# 514                 Brent                 39.2

# %%
dfnew.dtypes
# Out:
# Borough                 object
# 5_year_survival_rate    object
# dtype: object

# %%
dfnew['5_year_survival_rate'] = pd.to_numeric(dfnew['5_year_survival_rate'],errors='coerce')
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfnew.dtypes
# Out:
# Borough                  object
# 5_year_survival_rate    float64
# dtype: object

# %%
#merge the survival data with the completed borough data to complete data cleansing
df = df.merge(dfnew,on=['Borough'],how='left')

# %%
df['Radius'] = df['Radius'].astype('int64')

# %%
df.head()
# Out:
#                 Borough   Area  Latitude  Longitude  Radius  \
# 0  Barking and Dagenham  13.93   51.5607     0.1557    3003
# 1                Barnet  33.49   51.6252    -0.1517    4656
# 2                Bexley  23.38   51.4549     0.1505    3890
# 3                 Brent  16.70   51.5588    -0.2817    3288
# 4               Bromley  57.97   51.4039     0.0198    6126
#
#    5_year_survival_rate
# 0                  39.6
# 1                  40.9
# 2                  44.1
# 3                  39.2
# 4                  44.6

# %%
#Output to check if required
#df.to_csv('London_borough_data.csv')

# %% [markdown]
# #### Create a map of London with the boroughs superimposed on top.

# %%
#Get the central lats and longs for Toronto
address = 'London, UK'

geolocator = Nominatim(user_agent="lon_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of London are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of London are 51.4893335, -0.144055084527687.

# %%
map_london = folium.Map(location=[latitude, longitude])
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add borough markers to map
for lat, lng, bor in zip(df['Latitude'], df['Longitude'], df['Borough']):
    label = '{}'.format(bor)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)

# %%
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Use the FourSquare API to get venue data for the Toronto neighbourhoods

# %% [markdown]
# ##### Define Foursquare credentials

# %%
CLIENT_ID = 'FQK1QA11AK1OPXWQ1X1D4AVU1UKV1OV1SNOSJ04VVQJJGVHZ' # your Foursquare ID
CLIENT_SECRET = 'PWBEB4JGCJVP0XAFQ33YRC43ZMZIWXANE4LTCZ42XQNZRYYP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FQK1QA11AK1OPXWQ1X1D4AVU1UKV1OV1SNOSJ04VVQJJGVHZ
# CLIENT_SECRET:PWBEB4JGCJVP0XAFQ33YRC43ZMZIWXANE4LTCZ42XQNZRYYP

# %% [markdown]
# ##### Define function that will retrieve venue data for a borough

# %%
def getNearbyVenues(names, latitudes, longitudes, radius):
    
    LIMIT = 100
    venues_list=[]
    for name, lat, lng, rad in zip(names, latitudes, longitudes, radius):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            rad, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng,
            rad,
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough', 
                  'Latitude', 
                  'Longitude',
                  'Radius',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#Get venue data for the different boroughs
borough_venues = getNearbyVenues(names=df['Borough'],latitudes=df['Latitude'],longitudes=df['Longitude'],radius=df['Radius'])
# Out:
# Barking and Dagenham
# Barnet
# Bexley
# Brent
# Bromley
# Camden
# Croydon
# Ealing
# Enfield
# Greenwich
# Hackney
# Hammersmith and Fulham
# Haringey
# Harrow
# Havering
# Hillingdon
# Hounslow
# Islington
# Kensington and Chelsea
# Kingston upon Thames
# Lambeth
# Lewisham
# Merton
# Newham
# Redbridge
# Richmond upon Thames
# Southwark
# Sutton
# Tower Hamlets
# Waltham Forest
# Wandsworth
# Westminster

# %%
#Have a look at the data
print(borough_venues.shape)
borough_venues
# Out:
# (3100, 8)
#                    Borough  Latitude  Longitude  Radius  \
# 0     Barking and Dagenham   51.5607     0.1557    3003
# 1     Barking and Dagenham   51.5607     0.1557    3003
# 2     Barking and Dagenham   51.5607     0.1557    3003
# 3     Barking and Dagenham   51.5607     0.1557    3003
# 4     Barking and Dagenham   51.5607     0.1557    3003
# ...                    ...       ...        ...     ...
# 3095           Westminster   51.4973    -0.1372    2316
# 3096           Westminster   51.4973    -0.1372    2316
# 3097           Westminster   51.4973    -0.1372    2316
# 3098           Westminster   51.4973    -0.1372    2316
# 3099           Westminster   51.4973    -0.1372    2316
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 0                    Central Park       51.559560         0.161981
# 1                       The Range       51.575550         0.180254
# 2                    Hylands Park       51.572074         0.191155
# 3                    Costa Coffee       51.576890         0.179497
# 4               Harrow Lodge Park       51.555648         0.197926
# ...                           ...             ...              ...
# 3095  Victoria Embankment Gardens       51.508135        -0.122079
# 3096              Halcyon Gallery       51.511452        -0.143736
# 3097                The Connaught       51.510138        -0.149498
# 3098               Harvey Nichols       51.501543        -0.159742
# 3099               Hedonism Wines       51.510803        -0.147450
#
#               Venue Category
# 0                       Park
# 1     Furniture / Home Store
# 2                       Park
# 3                Coffee Shop
# 4                       Park
# ...                      ...
# 3095                  Garden
# 3096             Art Gallery
# 3097                   Hotel
# 3098        Department Store
# 3099               Wine Shop
#
# [3100 rows x 8 columns]

# %% [markdown]
# #### Check how many venues were returned for each borough

# %%
borough_venues.groupby('Borough').count()
# Out:
#                         Latitude  Longitude  Radius  Venue  Venue Latitude  \
# Borough
# Barking and Dagenham          79         79      79     79              79
# Barnet                       100        100     100    100             100
# Bexley                       100        100     100    100             100
# Brent                        100        100     100    100             100
# Bromley                      100        100     100    100             100
# Camden                       100        100     100    100             100
# Croydon                      100        100     100    100             100
# Ealing                       100        100     100    100             100
# Enfield                       92         92      92     92              92
# Greenwich                    100        100     100    100             100
# Hackney                      100        100     100    100             100
# Hammersmith and Fulham       100        100     100    100             100
# Haringey                     100        100     100    100             100
# Harrow                       100        100     100    100             100
# Havering                     100        100     100    100             100
# Hillingdon                    78         78      78     78              78
# Hounslow                     100        100     100    100             100
# Islington                    100        100     100    100             100
# Kensington and Chelsea       100        100     100    100             100
# Kingston upon Thames         100        100     100    100             100
# Lambeth                      100        100     100    100             100
# Lewisham                     100        100     100    100             100
# Merton                        71         71      71     71              71
# Newham                       100        100     100    100             100
# Redbridge                    100        100     100    100             100
# Richmond upon Thames         100        100     100    100             100
# Southwark                    100        100     100    100             100
# Sutton                        80         80      80     80              80
# Tower Hamlets                100        100     100    100             100
# Waltham Forest               100        100     100    100             100
# Wandsworth                   100        100     100    100             100
# Westminster                  100        100     100    100             100
#
#                         Venue Longitude  Venue Category
# Borough
# Barking and Dagenham                 79              79
# Barnet                              100             100
# Bexley                              100             100
# Brent                               100             100
# Bromley                             100             100
# Camden                              100             100
# Croydon                             100             100
# Ealing                              100             100
# Enfield                              92              92
# Greenwich                           100             100
# Hackney                             100             100
# Hammersmith and Fulham              100             100
# Haringey                            100             100
# Harrow                              100             100
# Havering                            100             100
# Hillingdon                           78              78
# Hounslow                            100             100
# Islington                           100             100
# Kensington and Chelsea              100             100
# Kingston upon Thames                100             100
# Lambeth                             100             100
# Lewisham                            100             100
# Merton                               71              71
# Newham                              100             100
# Redbridge                           100             100
# Richmond upon Thames                100             100
# Southwark                           100             100
# Sutton                               80              80
# Tower Hamlets                       100             100
# Waltham Forest                      100             100
# Wandsworth                          100             100
# Westminster                         100             100

# %% [markdown]
# #### Find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} unique categories.'.format(len(borough_venues['Venue Category'].unique())))
# Out:
# There are 263 unique categories.

# %% [markdown]
# #### Analyse each borough

# %%
# one hot encoding
borough_onehot = pd.get_dummies(borough_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighbourhood column back to dataframe
borough_onehot['Borough'] = borough_venues['Borough'] 

# move neighbourhood column to the first column
fixed_columns = [borough_onehot.columns[-1]] + list(borough_onehot.columns[:-1])
borough_onehot = borough_onehot[fixed_columns]

borough_onehot.tail()
# Out:
#           Borough  Afghan Restaurant  African Restaurant  Airport  \
# 3095  Westminster                  0                   0        0
# 3096  Westminster                  0                   0        0
# 3097  Westminster                  0                   0        0
# 3098  Westminster                  0                   0        0
# 3099  Westminster                  0                   0        0
#
#       American Restaurant  Aquarium  Argentinian Restaurant  Art Gallery  \
# 3095                    0         0                       0            0
# 3096                    0         0                       0            1
# 3097                    0         0                       0            0
# 3098                    0         0                       0            0
# 3099                    0         0                       0            0
#
#       Art Museum  Arts & Crafts Store  ...  Video Game Store  \
# 3095           0                    0  ...                 0
# 3096           0                    0  ...                 0
# 3097           0                    0  ...                 0
# 3098           0                    0  ...                 0
# 3099           0                    0  ...                 0
#
#       Vietnamese Restaurant  Warehouse Store  Waterfront  Windmill  Wine Bar  \
# 3095                      0                0           0         0         0
# 3096                      0                0           0         0         0
# 3097                      0                0           0         0         0
# 3098                      0                0           0         0         0
# 3099                      0                0           0         0         0
#
#       Wine Shop  Winery  Women's Store  Yoga Studio
# 3095          0       0              0            0
# 3096          0       0              0            0
# 3097          0       0              0            0
# 3098          0       0              0            0
# 3099          1       0              0            0
#
# [5 rows x 264 columns]

# %%
borough_onehot.shape
# Out:
# (3100, 264)

# %% [markdown]
# #### Group rows by borough and by taking the mean of the frequency of occurrence of each category

# %%
borough_grouped = borough_onehot.groupby('Borough').mean().reset_index()
borough_grouped
# Out:
#                    Borough  Afghan Restaurant  African Restaurant  Airport  \
# 0     Barking and Dagenham               0.00                0.00     0.00
# 1                   Barnet               0.00                0.00     0.00
# 2                   Bexley               0.00                0.00     0.00
# 3                    Brent               0.00                0.00     0.00
# 4                  Bromley               0.00                0.01     0.00
# 5                   Camden               0.01                0.00     0.00
# 6                  Croydon               0.00                0.01     0.00
# 7                   Ealing               0.00                0.00     0.00
# 8                  Enfield               0.00                0.00     0.00
# 9                Greenwich               0.00                0.01     0.01
# 10                 Hackney               0.00                0.00     0.00
# 11  Hammersmith and Fulham               0.00                0.00     0.00
# 12                Haringey               0.00                0.00     0.00
# 13                  Harrow               0.00                0.00     0.00
# 14                Havering               0.00                0.00     0.00
# 15              Hillingdon               0.00                0.00     0.00
# 16                Hounslow               0.00                0.00     0.00
# 17               Islington               0.01                0.00     0.00
# 18  Kensington and Chelsea               0.00                0.00     0.00
# 19    Kingston upon Thames               0.00                0.00     0.00
# 20                 Lambeth               0.00                0.00     0.00
# 21                Lewisham               0.00                0.00     0.00
# 22                  Merton               0.00                0.00     0.00
# 23                  Newham               0.00                0.01     0.01
# 24               Redbridge               0.00                0.00     0.00
# 25    Richmond upon Thames               0.00                0.00     0.00
# 26               Southwark               0.00                0.00     0.00
# 27                  Sutton               0.00                0.00     0.00
# 28           Tower Hamlets               0.00                0.00     0.00
# 29          Waltham Forest               0.00                0.00     0.00
# 30              Wandsworth               0.00                0.00     0.00
# 31             Westminster               0.00                0.00     0.00
#
#     American Restaurant  Aquarium  Argentinian Restaurant  Art Gallery  \
# 0              0.025316      0.00                0.000000         0.00
# 1              0.000000      0.00                0.000000         0.00
# 2              0.010000      0.00                0.000000         0.00
# 3              0.010000      0.00                0.000000         0.00
# 4              0.010000      0.00                0.000000         0.00
# 5              0.000000      0.00                0.000000         0.00
# 6              0.000000      0.00                0.000000         0.00
# 7              0.000000      0.00                0.000000         0.01
# 8              0.000000      0.00                0.000000         0.00
# 9              0.000000      0.00                0.000000         0.00
# 10             0.000000      0.00                0.010000         0.01
# 11             0.000000      0.00                0.010000         0.00
# 12             0.000000      0.00                0.000000         0.00
# 13             0.000000      0.00                0.000000         0.00
# 14             0.020000      0.00                0.000000         0.00
# 15             0.000000      0.00                0.000000         0.00
# 16             0.000000      0.00                0.000000         0.00
# 17             0.000000      0.00                0.000000         0.00
# 18             0.000000      0.00                0.000000         0.01
# 19             0.000000      0.00                0.000000         0.00
# 20             0.000000      0.00                0.000000         0.00
# 21             0.000000      0.01                0.000000         0.00
# 22             0.000000      0.00                0.014085         0.00
# 23             0.000000      0.00                0.010000         0.00
# 24             0.000000      0.00                0.000000         0.00
# 25             0.010000      0.00                0.020000         0.00
# 26             0.000000      0.00                0.000000         0.01
# 27             0.012500      0.00                0.000000         0.00
# 28             0.000000      0.00                0.010000         0.01
# 29             0.000000      0.00                0.000000         0.02
# 30             0.000000      0.00                0.000000         0.00
# 31             0.010000      0.00                0.010000         0.03
#
#     Art Museum  Arts & Crafts Store  ...  Video Game Store  \
# 0         0.00                 0.00  ...            0.0000
# 1         0.00                 0.00  ...            0.0000
# 2         0.00                 0.01  ...            0.0100
# 3         0.00                 0.00  ...            0.0000
# 4         0.00                 0.00  ...            0.0000
# 5         0.00                 0.01  ...            0.0000
# 6         0.00                 0.01  ...            0.0000
# 7         0.00                 0.00  ...            0.0000
# 8         0.00                 0.00  ...            0.0000
# 9         0.00                 0.00  ...            0.0000
# 10        0.00                 0.00  ...            0.0000
# 11        0.00                 0.00  ...            0.0000
# 12        0.00                 0.00  ...            0.0000
# 13        0.00                 0.00  ...            0.0000
# 14        0.00                 0.00  ...            0.0000
# 15        0.00                 0.00  ...            0.0000
# 16        0.00                 0.00  ...            0.0000
# 17        0.01                 0.02  ...            0.0000
# 18        0.00                 0.00  ...            0.0000
# 19        0.00                 0.00  ...            0.0000
# 20        0.00                 0.00  ...            0.0000
# 21        0.00                 0.00  ...            0.0000
# 22        0.00                 0.00  ...            0.0000
# 23        0.00                 0.00  ...            0.0000
# 24        0.00                 0.00  ...            0.0000
# 25        0.00                 0.00  ...            0.0000
# 26        0.02                 0.00  ...            0.0000
# 27        0.00                 0.00  ...            0.0125
# 28        0.00                 0.00  ...            0.0000
# 29        0.00                 0.01  ...            0.0000
# 30        0.00                 0.01  ...            0.0000
# 31        0.03                 0.00  ...            0.0000
#
#     Vietnamese Restaurant  Warehouse Store  Waterfront  Windmill  Wine Bar  \
# 0                0.000000           0.0000        0.00      0.00      0.00
# 1                0.000000           0.0000        0.00      0.00      0.00
# 2                0.000000           0.0100        0.00      0.00      0.00
# 3                0.000000           0.0100        0.00      0.00      0.00
# 4                0.000000           0.0000        0.00      0.00      0.00
# 5                0.000000           0.0000        0.00      0.00      0.02
# 6                0.000000           0.0100        0.00      0.00      0.00
# 7                0.010000           0.0000        0.00      0.00      0.01
# 8                0.000000           0.0000        0.00      0.00      0.00
# 9                0.010000           0.0100        0.00      0.00      0.00
# 10               0.010000           0.0000        0.00      0.00      0.00
# 11               0.010000           0.0000        0.00      0.00      0.00
# 12               0.000000           0.0000        0.00      0.00      0.00
# 13               0.000000           0.0000        0.00      0.00      0.00
# 14               0.000000           0.0000        0.00      0.01      0.00
# 15               0.000000           0.0000        0.00      0.00      0.00
# 16               0.000000           0.0100        0.00      0.00      0.00
# 17               0.000000           0.0000        0.00      0.00      0.00
# 18               0.000000           0.0000        0.00      0.00      0.01
# 19               0.000000           0.0000        0.00      0.00      0.00
# 20               0.000000           0.0000        0.00      0.00      0.00
# 21               0.000000           0.0000        0.00      0.00      0.00
# 22               0.014085           0.0000        0.00      0.00      0.00
# 23               0.010000           0.0100        0.00      0.00      0.01
# 24               0.000000           0.0000        0.00      0.00      0.00
# 25               0.010000           0.0000        0.01      0.00      0.00
# 26               0.000000           0.0000        0.00      0.00      0.01
# 27               0.000000           0.0125        0.00      0.00      0.00
# 28               0.000000           0.0000        0.00      0.00      0.00
# 29               0.000000           0.0100        0.00      0.00      0.01
# 30               0.000000           0.0000        0.00      0.00      0.02
# 31               0.000000           0.0000        0.00      0.00      0.01
#
#     Wine Shop  Winery  Women's Store  Yoga Studio
# 0        0.00    0.00       0.012658         0.00
# 1        0.00    0.00       0.000000         0.00
# 2        0.00    0.00       0.000000         0.00
# 3        0.00    0.00       0.000000         0.00
# 4        0.00    0.00       0.000000         0.00
# 5        0.00    0.00       0.000000         0.00
# 6        0.00    0.00       0.000000         0.00
# 7        0.00    0.00       0.000000         0.00
# 8        0.00    0.00       0.000000         0.00
# 9        0.00    0.00       0.000000         0.00
# 10       0.02    0.00       0.000000         0.04
# 11       0.00    0.00       0.000000         0.00
# 12       0.00    0.00       0.000000         0.00
# 13       0.00    0.00       0.000000         0.00
# 14       0.00    0.00       0.010000         0.00
# 15       0.00    0.00       0.000000         0.00
# 16       0.00    0.00       0.000000         0.00
# 17       0.01    0.00       0.000000         0.01
# 18       0.00    0.00       0.000000         0.01
# 19       0.00    0.00       0.000000         0.00
# 20       0.00    0.01       0.000000         0.02
# 21       0.00    0.00       0.000000         0.00
# 22       0.00    0.00       0.000000         0.00
# 23       0.00    0.00       0.000000         0.00
# 24       0.00    0.00       0.000000         0.00
# 25       0.00    0.00       0.000000         0.00
# 26       0.00    0.00       0.000000         0.00
# 27       0.00    0.00       0.012500         0.00
# 28       0.00    0.00       0.000000         0.00
# 29       0.00    0.00       0.000000         0.00
# 30       0.00    0.00       0.000000         0.01
# 31       0.02    0.00       0.000000         0.00
#
# [32 rows x 264 columns]

# %%
borough_grouped.tail()
# Out:
#            Borough  Afghan Restaurant  African Restaurant  Airport  \
# 27          Sutton                0.0                 0.0      0.0
# 28   Tower Hamlets                0.0                 0.0      0.0
# 29  Waltham Forest                0.0                 0.0      0.0
# 30      Wandsworth                0.0                 0.0      0.0
# 31     Westminster                0.0                 0.0      0.0
#
#     American Restaurant  Aquarium  Argentinian Restaurant  Art Gallery  \
# 27               0.0125       0.0                    0.00         0.00
# 28               0.0000       0.0                    0.01         0.01
# 29               0.0000       0.0                    0.00         0.02
# 30               0.0000       0.0                    0.00         0.00
# 31               0.0100       0.0                    0.01         0.03
#
#     Art Museum  Arts & Crafts Store  ...  Video Game Store  \
# 27        0.00                 0.00  ...            0.0125
# 28        0.00                 0.00  ...            0.0000
# 29        0.00                 0.01  ...            0.0000
# 30        0.00                 0.01  ...            0.0000
# 31        0.03                 0.00  ...            0.0000
#
#     Vietnamese Restaurant  Warehouse Store  Waterfront  Windmill  Wine Bar  \
# 27                    0.0           0.0125         0.0       0.0      0.00
# 28                    0.0           0.0000         0.0       0.0      0.00
# 29                    0.0           0.0100         0.0       0.0      0.01
# 30                    0.0           0.0000         0.0       0.0      0.02
# 31                    0.0           0.0000         0.0       0.0      0.01
#
#     Wine Shop  Winery  Women's Store  Yoga Studio
# 27       0.00     0.0         0.0125         0.00
# 28       0.00     0.0         0.0000         0.00
# 29       0.00     0.0         0.0000         0.00
# 30       0.00     0.0         0.0000         0.01
# 31       0.02     0.0         0.0000         0.00
#
# [5 rows x 264 columns]

# %%
borough_grouped.to_csv('borough_grouped.csv')

# %% [markdown]
# #### Print each borough along with the top 5 most common venues

# %%
num_top_venues = 5

for bor in borough_grouped['Borough']:
    print("---",bor,"---")
    temp = borough_grouped[borough_grouped['Borough'] == bor].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# --- Barking and Dagenham ---
#             venue  freq
# 0   Grocery Store  0.11
# 1     Coffee Shop  0.09
# 2            Park  0.06
# 3     Supermarket  0.06
# 4  Clothing Store  0.04
#
#
# --- Barnet ---
#                 venue  freq
# 0                Café  0.13
# 1         Coffee Shop  0.09
# 2  Turkish Restaurant  0.07
# 3                Park  0.06
# 4                 Pub  0.05
#
#
# --- Bexley ---
#                 venue  freq
# 0       Grocery Store  0.16
# 1                 Pub  0.15
# 2         Supermarket  0.07
# 3   Convenience Store  0.04
# 4  Italian Restaurant  0.04
#
#
# --- Brent ---
#                venue  freq
# 0        Coffee Shop  0.09
# 1  Indian Restaurant  0.09
# 2              Hotel  0.06
# 3     Clothing Store  0.05
# 4     Sandwich Place  0.05
#
#
# --- Bromley ---
#                   venue  freq
# 0                   Pub  0.16
# 1           Coffee Shop  0.09
# 2                  Park  0.09
# 3  Gym / Fitness Center  0.06
# 4           Pizza Place  0.04
#
#
# --- Camden ---
#          venue  freq
# 0  Coffee Shop  0.08
# 1        Hotel  0.05
# 2    Bookstore  0.05
# 3  Pizza Place  0.04
# 4      Theater  0.04
#
#
# --- Croydon ---
#            venue  freq
# 0            Pub  0.13
# 1    Coffee Shop  0.10
# 2  Grocery Store  0.08
# 3           Park  0.07
# 4    Pizza Place  0.03
#
#
# --- Ealing ---
#          venue  freq
# 0          Pub  0.14
# 1  Coffee Shop  0.11
# 2         Park  0.11
# 3        Hotel  0.06
# 4  Pizza Place  0.03
#
#
# --- Enfield ---
#                   venue  freq
# 0           Coffee Shop  0.10
# 1                   Pub  0.09
# 2  Gym / Fitness Center  0.07
# 3         Garden Center  0.07
# 4    Turkish Restaurant  0.05
#
#
# --- Greenwich ---
#             venue  freq
# 0             Pub  0.09
# 1   Grocery Store  0.07
# 2  Clothing Store  0.07
# 3     Coffee Shop  0.06
# 4     Supermarket  0.05
#
#
# --- Hackney ---
#          venue  freq
# 0          Pub  0.12
# 1         Café  0.09
# 2  Coffee Shop  0.09
# 3       Bakery  0.06
# 4  Yoga Studio  0.04
#
#
# --- Hammersmith and Fulham ---
#          venue  freq
# 0          Pub  0.13
# 1         Café  0.08
# 2  Coffee Shop  0.07
# 3         Park  0.04
# 4    Gastropub  0.04
#
#
# --- Haringey ---
#                 venue  freq
# 0                Café  0.10
# 1  Turkish Restaurant  0.09
# 2         Coffee Shop  0.07
# 3                 Pub  0.06
# 4                Park  0.06
#
#
# --- Harrow ---
#                   venue  freq
# 0     Indian Restaurant  0.17
# 1           Coffee Shop  0.12
# 2                   Pub  0.07
# 3         Grocery Store  0.05
# 4  Gym / Fitness Center  0.05
#
#
# --- Havering ---
#            venue  freq
# 0    Coffee Shop  0.13
# 1            Pub  0.12
# 2  Grocery Store  0.08
# 3           Park  0.06
# 4    Supermarket  0.04
#
#
# --- Hillingdon ---
#                venue  freq
# 0                Pub  0.13
# 1  Indian Restaurant  0.08
# 2        Coffee Shop  0.08
# 3              Hotel  0.05
# 4        Golf Course  0.05
#
#
# --- Hounslow ---
#                venue  freq
# 0                Pub  0.12
# 1        Coffee Shop  0.08
# 2  Indian Restaurant  0.08
# 3               Park  0.05
# 4              Hotel  0.05
#
#
# --- Islington ---
#                       venue  freq
# 0                       Pub  0.15
# 1               Coffee Shop  0.06
# 2                      Café  0.06
# 3                    Bakery  0.03
# 4  Mediterranean Restaurant  0.03
#
#
# --- Kensington and Chelsea ---
#                 venue  freq
# 0                 Pub  0.07
# 1          Restaurant  0.07
# 2  Italian Restaurant  0.06
# 3                Café  0.05
# 4              Bakery  0.04
#
#
# --- Kingston upon Thames ---
#          venue  freq
# 0          Pub  0.15
# 1         Café  0.08
# 2  Coffee Shop  0.07
# 3         Park  0.05
# 4    Gastropub  0.04
#
#
# --- Lambeth ---
#          venue  freq
# 0  Coffee Shop  0.08
# 1          Pub  0.07
# 2         Park  0.05
# 3  Pizza Place  0.04
# 4         Café  0.04
#
#
# --- Lewisham ---
#          venue  freq
# 0          Pub  0.19
# 1  Coffee Shop  0.11
# 2         Café  0.10
# 3    Gastropub  0.05
# 4         Park  0.05
#
#
# --- Merton ---
#               venue  freq
# 0              Park  0.11
# 1               Pub  0.08
# 2  Sushi Restaurant  0.06
# 3       Supermarket  0.04
# 4              Café  0.04
#
#
# --- Newham ---
#             venue  freq
# 0           Hotel  0.09
# 1     Coffee Shop  0.08
# 2             Pub  0.07
# 3            Park  0.05
# 4  Clothing Store  0.04
#
#
# --- Redbridge ---
#                venue  freq
# 0      Grocery Store  0.10
# 1               Park  0.09
# 2  Indian Restaurant  0.08
# 3        Supermarket  0.07
# 4                Pub  0.06
#
#
# --- Richmond upon Thames ---
#                 venue  freq
# 0                 Pub  0.14
# 1  Italian Restaurant  0.06
# 2                Park  0.06
# 3                Café  0.05
# 4         Coffee Shop  0.05
#
#
# --- Southwark ---
#                 venue  freq
# 0         Coffee Shop  0.11
# 1               Hotel  0.08
# 2  Italian Restaurant  0.04
# 3        Cocktail Bar  0.04
# 4      Scenic Lookout  0.04
#
#
# --- Sutton ---
#            venue  freq
# 0            Pub  0.12
# 1  Grocery Store  0.10
# 2    Coffee Shop  0.09
# 3           Park  0.08
# 4    Supermarket  0.05
#
#
# --- Tower Hamlets ---
#           venue  freq
# 0   Coffee Shop  0.08
# 1  Burger Joint  0.05
# 2         Hotel  0.05
# 3          Park  0.04
# 4         Plaza  0.04
#
#
# --- Waltham Forest ---
#          venue  freq
# 0          Pub  0.14
# 1  Coffee Shop  0.10
# 2         Café  0.07
# 3         Park  0.05
# 4  Pizza Place  0.05
#
#
# --- Wandsworth ---
#          venue  freq
# 0  Coffee Shop  0.12
# 1          Pub  0.12
# 2         Park  0.12
# 3  Pizza Place  0.06
# 4         Café  0.06
#
#
# --- Westminster ---
#             venue  freq
# 0           Hotel  0.18
# 1        Boutique  0.05
# 2         Theater  0.05
# 3  Clothing Store  0.04
# 4          Garden  0.04

# %% [markdown]
# #### Put that into a *pandas* dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# #### Create the new dataframe and display the top 10 venues for each borough.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Borough']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
borough_venues_sorted = pd.DataFrame(columns=columns)
borough_venues_sorted['Borough'] = borough_grouped['Borough']

for ind in np.arange(borough_grouped.shape[0]):
    borough_venues_sorted.iloc[ind, 1:] = return_most_common_venues(borough_grouped.iloc[ind, :], num_top_venues)

borough_venues_sorted.head()
# Out:
#                 Borough 1st Most Common Venue 2nd Most Common Venue  \
# 0  Barking and Dagenham         Grocery Store           Coffee Shop
# 1                Barnet                  Café           Coffee Shop
# 2                Bexley         Grocery Store                   Pub
# 3                 Brent     Indian Restaurant           Coffee Shop
# 4               Bromley                   Pub           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue   5th Most Common Venue  \
# 0           Supermarket                  Park  Furniture / Home Store
# 1    Turkish Restaurant                  Park                     Pub
# 2           Supermarket  Fast Food Restaurant           Train Station
# 3                 Hotel        Clothing Store          Sandwich Place
# 4                  Park  Gym / Fitness Center             Pizza Place
#
#   6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0            Restaurant  Fast Food Restaurant            Clothing Store
# 1         Grocery Store                Bakery        Italian Restaurant
# 2           Coffee Shop     Convenience Store        Italian Restaurant
# 3  Gym / Fitness Center         Grocery Store                      Park
# 4    Italian Restaurant           Supermarket  Mediterranean Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0              Bus Stop              Multiplex
# 1  Gym / Fitness Center       Greek Restaurant
# 2        Clothing Store            Pizza Place
# 3           Pizza Place  Portuguese Restaurant
# 4             Gastropub      Indian Restaurant

# %% [markdown]
# #### Cluster Boroughs

# %% [markdown]
# Run *k*-means to cluster the boroughs into 5 clusters.

# %%
# set number of clusters
kclusters = 5

borough_grouped_clustering = borough_grouped.drop('Borough', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(borough_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([0, 2, 0, 1, 2, 4, 2, 2, 2, 0, 2, 2, 2, 1, 0, 1, 1, 2, 2, 2, 2, 2,
#        2, 1, 0, 2, 4, 0, 4, 2, 2, 3], dtype=int32)

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each borough.

# %%
# add clustering labels
borough_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

borough_merged = df

# merge borough_grouped with borough_data to add latitude/longitude for each borough
borough_merged = borough_merged.join(borough_venues_sorted.set_index('Borough'), on='Borough')

borough_merged.tail() # check the last columns!
# Out:
#            Borough   Area  Latitude  Longitude  Radius  5_year_survival_rate  \
# 27          Sutton  16.93   51.3618    -0.1945    3310                  45.1
# 28   Tower Hamlets   7.63   51.5099    -0.0059    2222                  35.9
# 29  Waltham Forest  14.99   51.5908    -0.0134    3115                  37.5
# 30      Wandsworth  13.23   51.4567    -0.1910    2926                  39.9
# 31     Westminster   8.29   51.4973    -0.1372    2316                  35.6
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 27               0                   Pub         Grocery Store
# 28               4           Coffee Shop          Burger Joint
# 29               2                   Pub           Coffee Shop
# 30               2                   Pub                  Park
# 31               3                 Hotel              Boutique
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 27           Coffee Shop                  Park    Italian Restaurant
# 28                 Hotel                 Plaza                   Bar
# 29                  Café                  Park           Pizza Place
# 30           Coffee Shop                  Café           Pizza Place
# 31               Theater                 Plaza        Clothing Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 27           Supermarket                  Café        Sandwich Place
# 28                  Park                Lounge    Italian Restaurant
# 29            Restaurant               Brewery    Turkish Restaurant
# 30                Bakery           Supermarket     French Restaurant
# 31                Garden                  Park           Art Gallery
#
#    9th Most Common Venue 10th Most Common Venue
# 27        Clothing Store   Gym / Fitness Center
# 28                   Pub   Gym / Fitness Center
# 29           Supermarket                 Bakery
# 30       Thai Restaurant         Breakfast Spot
# 31            Art Museum                 Lounge

# %% [markdown]
# Finally, visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(borough_merged['Latitude'], borough_merged['Longitude'], borough_merged['Borough'], borough_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster + 1), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Closer look at the cluster data

# %% [markdown]
# #### Cluster 1

# %%
borough_merged.loc[borough_merged['Cluster Labels'] == 0, borough_merged.columns[[0] + [1] + list(range(5, borough_merged.shape[1]))]]
# Out:
#                  Borough   Area  5_year_survival_rate  Cluster Labels  \
# 0   Barking and Dagenham  13.93                  39.6               0
# 2                 Bexley  23.38                  44.1               0
# 9              Greenwich  18.28                  40.0               0
# 14              Havering  43.35                  45.2               0
# 24             Redbridge  21.78                  39.9               0
# 27                Sutton  16.93                  45.1               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0          Grocery Store           Coffee Shop           Supermarket
# 2          Grocery Store                   Pub           Supermarket
# 9                    Pub         Grocery Store        Clothing Store
# 14           Coffee Shop                   Pub         Grocery Store
# 24         Grocery Store                  Park     Indian Restaurant
# 27                   Pub         Grocery Store           Coffee Shop
#
#    4th Most Common Venue   5th Most Common Venue 6th Most Common Venue  \
# 0                   Park  Furniture / Home Store            Restaurant
# 2   Fast Food Restaurant           Train Station           Coffee Shop
# 9            Coffee Shop                   Hotel                  Park
# 14                  Park             Supermarket  Fast Food Restaurant
# 24           Supermarket                     Pub                Bakery
# 27                  Park      Italian Restaurant           Supermarket
#
#    7th Most Common Venue   8th Most Common Venue 9th Most Common Venue  \
# 0   Fast Food Restaurant          Clothing Store              Bus Stop
# 2      Convenience Store      Italian Restaurant        Clothing Store
# 9            Supermarket    Gym / Fitness Center                Bakery
# 14    Italian Restaurant  Furniture / Home Store                  Café
# 24  Fast Food Restaurant             Coffee Shop        Clothing Store
# 27                  Café          Sandwich Place        Clothing Store
#
#    10th Most Common Venue
# 0               Multiplex
# 2             Pizza Place
# 9    Fast Food Restaurant
# 14                 Bakery
# 24            Pizza Place
# 27   Gym / Fitness Center

# %% [markdown]
# There is a high incidence of grocery stores and pubs in these boroughs. This would indicate these are residential areas. There is a good mix of venues, such as parks, restaurants, shops and coffee shops indicating these are busy areas during the day, but night life is limited to pubs and a few restaurants. These boroughs are on the outskirts of London, generally to the East.
# Cluster name:  Residential

# %% [markdown]
# #### Cluster 2

# %%
borough_merged.loc[borough_merged['Cluster Labels'] == 1, borough_merged.columns[[0]+ [1] + list(range(5, borough_merged.shape[1]))]]
# Out:
#        Borough   Area  5_year_survival_rate  Cluster Labels  \
# 3        Brent  16.70                  39.2               1
# 13      Harrow  19.49                  43.4               1
# 15  Hillingdon  44.67                  44.3               1
# 16    Hounslow  21.61                  43.4               1
# 23      Newham  13.98                  36.8               1
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 3      Indian Restaurant           Coffee Shop                 Hotel
# 13     Indian Restaurant           Coffee Shop                   Pub
# 15                   Pub           Coffee Shop     Indian Restaurant
# 16                   Pub           Coffee Shop     Indian Restaurant
# 23                 Hotel           Coffee Shop                   Pub
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 3         Clothing Store        Sandwich Place  Gym / Fitness Center
# 13  Gym / Fitness Center         Grocery Store           Supermarket
# 15           Golf Course                 Hotel           Supermarket
# 16                  Park                 Hotel         Grocery Store
# 23                  Park         Grocery Store        Clothing Store
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 3          Grocery Store                  Park           Pizza Place
# 13                  Park                  Café        Ice Cream Shop
# 15                  Park                   Bar  Gym / Fitness Center
# 16           Pizza Place         Rugby Stadium        Clothing Store
# 23  Gym / Fitness Center           Supermarket                 Plaza
#
#    10th Most Common Venue
# 3   Portuguese Restaurant
# 13                    Bar
# 15          Grocery Store
# 16   Gym / Fitness Center
# 23        Thai Restaurant

# %% [markdown]
# There is a high incidence of Indian restaurants, along with coffee shops, pubs and hotels. This also looks to be a residential area but livelier in the evening. The boroughs are on the outskirts of London, generally to the west and north.
# Cluster name: Residential with love of Indian food

# %% [markdown]
# #### Cluster 3

# %%
borough_merged.loc[borough_merged['Cluster Labels'] == 2, borough_merged.columns[[0] + [1] + list(range(5, borough_merged.shape[1]))]]
# Out:
#                    Borough   Area  5_year_survival_rate  Cluster Labels  \
# 1                   Barnet  33.49                  40.9               2
# 4                  Bromley  57.97                  44.6               2
# 6                  Croydon  33.41                  39.4               2
# 7                   Ealing  21.44                  42.5               2
# 8                  Enfield  31.74                  43.7               2
# 10                 Hackney   7.36                  43.5               2
# 11  Hammersmith and Fulham   6.33                  35.5               2
# 12                Haringey  11.42                  40.7               2
# 17               Islington   5.74                  38.1               2
# 18  Kensington and Chelsea   4.68                  38.9               2
# 19    Kingston upon Thames  14.38                  50.0               2
# 20                 Lambeth  10.36                  25.0               2
# 21                Lewisham  13.57                  42.4               2
# 22                  Merton  14.52                  42.5               2
# 25    Richmond upon Thames  22.17                  45.8               2
# 29          Waltham Forest  14.99                  37.5               2
# 30              Wandsworth  13.23                  39.9               2
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 1                   Café           Coffee Shop    Turkish Restaurant
# 4                    Pub           Coffee Shop                  Park
# 6                    Pub           Coffee Shop         Grocery Store
# 7                    Pub           Coffee Shop                  Park
# 8            Coffee Shop                   Pub         Garden Center
# 10                   Pub                  Café           Coffee Shop
# 11                   Pub                  Café           Coffee Shop
# 12                  Café    Turkish Restaurant           Coffee Shop
# 17                   Pub                  Café           Coffee Shop
# 18                   Pub            Restaurant    Italian Restaurant
# 19                   Pub                  Café           Coffee Shop
# 20           Coffee Shop                   Pub                  Park
# 21                   Pub           Coffee Shop                  Café
# 22                  Park                   Pub      Sushi Restaurant
# 25                   Pub                  Park    Italian Restaurant
# 29                   Pub           Coffee Shop                  Café
# 30                   Pub                  Park           Coffee Shop
#
#    4th Most Common Venue     5th Most Common Venue 6th Most Common Venue  \
# 1                   Park                       Pub         Grocery Store
# 4   Gym / Fitness Center               Pizza Place    Italian Restaurant
# 6                   Park  Mediterranean Restaurant                  Café
# 7                  Hotel      Gym / Fitness Center           Pizza Place
# 8   Gym / Fitness Center               Supermarket    Turkish Restaurant
# 10                Bakery               Yoga Studio             Bookstore
# 11                  Park                 Gastropub       Thai Restaurant
# 12                  Park                       Pub                Bakery
# 17                Bakery  Mediterranean Restaurant        Ice Cream Shop
# 18                  Café      Gym / Fitness Center                 Hotel
# 19                  Park                    Garden             Gastropub
# 20           Pizza Place                    Market               Brewery
# 21                  Park                 Gastropub    Italian Restaurant
# 22                  Café               Supermarket               Theater
# 25                  Café               Coffee Shop                Garden
# 29                  Park               Pizza Place            Restaurant
# 30                  Café               Pizza Place                Bakery
#
#     7th Most Common Venue     8th Most Common Venue 9th Most Common Venue  \
# 1                  Bakery        Italian Restaurant  Gym / Fitness Center
# 4             Supermarket  Mediterranean Restaurant             Gastropub
# 6          Clothing Store         Indian Restaurant           Pizza Place
# 7           Grocery Store                 Gastropub    Italian Restaurant
# 8        Greek Restaurant                      Café         Grocery Store
# 10           Cocktail Bar                   Brewery           Pizza Place
# 11      Indian Restaurant                     Hotel     French Restaurant
# 12            Pizza Place  Mediterranean Restaurant     Indian Restaurant
# 17                Theater               Pizza Place                  Park
# 18                 Bakery              Burger Joint     Indian Restaurant
# 19        Thai Restaurant        Italian Restaurant                 Hotel
# 20                   Café                Restaurant      Tapas Restaurant
# 21      Indian Restaurant        Turkish Restaurant           Supermarket
# 22  Portuguese Restaurant               Coffee Shop  Fast Food Restaurant
# 25          Rugby Stadium                    Bakery                 Hotel
# 29                Brewery        Turkish Restaurant           Supermarket
# 30            Supermarket         French Restaurant       Thai Restaurant
#
#      10th Most Common Venue
# 1          Greek Restaurant
# 4         Indian Restaurant
# 6   South Indian Restaurant
# 7          Sushi Restaurant
# 8                      Park
# 10                     Park
# 11              Pizza Place
# 12         Greek Restaurant
# 17              Music Venue
# 18                   Garden
# 19     Gym / Fitness Center
# 20     Caribbean Restaurant
# 21            Grocery Store
# 22           Breakfast Spot
# 25               Restaurant
# 29                   Bakery
# 30           Breakfast Spot

# %% [markdown]
# These boroughs really are dominated pubs and coffee shops and restaurants. There are few grocery stores, indicating the local people enjoy eating out during the day and night.
# Cluster Name: Pub and café society

# %% [markdown]
# #### Cluster 4

# %%
borough_merged.loc[borough_merged['Cluster Labels'] == 3, borough_merged.columns[[0]+ [1] + list(range(5, borough_merged.shape[1]))]]
# Out:
#         Borough  Area  5_year_survival_rate  Cluster Labels  \
# 31  Westminster  8.29                  35.6               3
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 31                 Hotel              Boutique               Theater
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 31                 Plaza        Clothing Store                Garden
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 31                  Park           Art Gallery            Art Museum
#
#    10th Most Common Venue
# 31                 Lounge

# %% [markdown]
# This cluster is clearly unique, dominated by hotels and theatres, and cultural venues during the day. Central London.
# Cluster name: Cultural

# %% [markdown]
# #### Cluster 5

# %%
borough_merged.loc[borough_merged['Cluster Labels'] == 4, borough_merged.columns[[1] + list(range(5, borough_merged.shape[1]))]]
# Out:
#      Area  5_year_survival_rate  Cluster Labels 1st Most Common Venue  \
# 5    8.40                  39.5               4           Coffee Shop
# 26  11.14                  39.8               4           Coffee Shop
# 28   7.63                  35.9               4           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5              Bookstore                 Hotel           Pizza Place
# 26                 Hotel    Italian Restaurant          Cocktail Bar
# 28          Burger Joint                 Hotel                 Plaza
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5                Theater    Seafood Restaurant                Bakery
# 26        Scenic Lookout               Theater                  Café
# 28                   Bar                  Park                Lounge
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 5             Steakhouse                 Canal          Grocery Store
# 26         Grocery Store                Garden             Steakhouse
# 28    Italian Restaurant                   Pub   Gym / Fitness Center

# %% [markdown]
# This doesn't look like this a huge residential area, as there are a small number of grocery stores, however the large number of coffee shops would indicate the area is busier in the day time. Although the area may attract tourists staying overnight as there are hotels, a some restuarants and theatres.

# %% [markdown]
# These boroughs are dominated by coffee shops but would be quieter in the evening. Perhaps less residential but more for tourists with its plentiful hotels. This is central London.
# Cluster name:  Coffee shop and tourist.
